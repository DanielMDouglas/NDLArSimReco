# %%
from NDLArSimReco.validation import plots as vp
from NDeventDisplay import plotting as evd
from LarpixParser import event_parser as EvtParser
import os
import yaml
import h5py
import numpy as np

# %%
manifestPath = os.path.join(os.getcwd(),
                            "../NDLArSimReco/manifests/localTestManifest.yaml")
with open(manifestPath) as mf:
    manifest = yaml.load(mf, Loader = yaml.FullLoader)
    
dataList = [h5py.File(manifest['trainfile'])]

# %%
vp.makePlot(vp.SpatialDistributionPlot, dataList)

# %%
vp.makePlot(vp.MultiplicityPlot, dataList)

# %%
vp.makePlot(vp.PrimaryTypePlot, dataList)

# %%
vp.makePlot(vp.MomentumPrimary2dPlot, dataList)

# %%
vp.makePlot(vp.MomentumPrimary1dPlot, dataList)

# %%
vp.makePlot(vp.EnergyPrimary2dPlot, dataList)

# %%
vp.makePlot(vp.EnergyPrimary1dPlot, dataList)

# %%
vp.makePlot(vp.EdepRatioPrimary1dPlot, dataList)

# %%
vp.makePlot(vp.EdepTrackLength2dPlot, dataList)

# %%
# %matplotlib notebook

nDisplays = 5
fileChoices = np.random.choice(len(dataList), 
                               size = nDisplays, 
                               replace = True)
for fileInd in fileChoices:
    eventChoice = np.random.choice(nEvents)
    evd.evd_ndlar(dataList[fileInd], eventChoice)
# Out:
# 899
# [0, 320.0]
# <img src="data:image/png;base64,..." width="640">
# 899
# [0, 320.0]
# <img src="data:image/png;base64,..." width="640">
# 899
# [0, 320.0]
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_227650/3673402145.py in <module>
#       9     print(nEvents)
#      10     eventChoice = np.random.choice(nEvents)
# ---> 11     evd.evd_ndlar(dataList[fileInd], eventChoice)
#
# ~/.local/lib/python3.10/site-packages/NDeventDisplay/plotting.py in evd_ndlar(larpixFile, eventid)
#      32
#      33     draw_boundaries(ax, config)
# ---> 34     plot_event(ax, packets, eventid, t0_grp, geom_dict, run_config)
#      35     plot_tracks(ax, packets, tracks, assn, eventid, t0_grp, geom_dict, run_config)
#      36
#
# ~/.local/lib/python3.10/site-packages/NDeventDisplay/plotting.py in plot_event(ax, packets, event_id, t0_grp, geom_dict, run_config)
#     100
#     101 def plot_event(ax, packets, event_id, t0_grp, geom_dict, run_config):
# --> 102     t0 = t0_grp[event_id][0]
#     103     ti = t0 + run_config['time_interval'][0]/run_config['CLOCK_CYCLE']
#     104     tf = t0 + run_config['time_interval'][1]/run_config['CLOCK_CYCLE']
#
# IndexError: index 874 is out of bounds for axis 0 with size 850
